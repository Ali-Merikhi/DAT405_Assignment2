# %% [markdown]
# <a href="https://colab.research.google.com/github/Ali-Merikhi/DAT405_Assignment2/blob/main/assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import pandas as pd

# Reads the csv-file
df = pd.read_csv('data_assignment2.csv')
area = 'Living_area'
price = 'Selling_price'

# Filters the data set to selling price above 2,4 million
filterOutliers = df[df[price] > 2400000]

# Variables without filtering
x = df[area]
y = df[price]

#x = filterOutliers[area]
#y = filterOutliers[price]

# Variable for linear regression and creates a 2D axis
linReg = LinearRegression(fit_intercept=True)
linReg.fit(x[:, np.newaxis], y)

# Defines the reach of the line
xFit = np.linspace(50, 250, 200)
yFit = linReg.predict(xFit[:, np.newaxis])

# Plots the results
plt.scatter(x, y)
plt.plot(xFit, yFit)
plt.show()
# Out:
# C:\Users\Albert\AppData\Local\Temp\ipykernel_4352\2263184250.py:23: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   linReg.fit(x[:, np.newaxis], y)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import pandas as pd

# Reads the csv-file
df = pd.read_csv('data_assignment2.csv')
area = 'Living_area'
price = 'Selling_price'

# Filters the data set to selling price above 2,4 million
filterOutliers = df[df[price] > 2400000]

# Variables without filtering
#x = df[area]
#y = df[price]

#Variables with filtering
x = filterOutliers[area]
y = filterOutliers[price]

# Variable for linear regression and creates a 2D axis
linReg = LinearRegression(fit_intercept=True)
linReg.fit(x[:, np.newaxis], y)

# Defines the reach of the line
xFit = np.linspace(50, 250, 200)
yFit = linReg.predict(xFit[:, np.newaxis])

# Plots the results
plt.scatter(x, y)
plt.plot(xFit, yFit)
plt.show()
# Out:
# C:\Users\Albert\AppData\Local\Temp\ipykernel_4352\4055779122.py:24: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   linReg.fit(x[:, np.newaxis], y)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import pandas as pd

# Reads the csv-file
df = pd.read_csv('data_assignment2.csv')
area = 'Living_area'
price = 'Selling_price'

# Filters the data set to selling price above 2,4 million
filterOutliers = df[df[price] > 2400000]

#Variables with filtering
x = filterOutliers[area]
y = filterOutliers[price]

# Variable for linear regression and creates a 2D axis
linReg = LinearRegression(fit_intercept=True)
linReg.fit(x[:, np.newaxis], y)

# Variables for the slope and intercept from the sklearn.linear_model library
slope = linReg.coef_
intercept = linReg.intercept_

# Prints out the slope and intercept
print('Slope coefficient: ', slope)
print('Intercept: ', intercept)
# Out:
# Slope coefficient:  [23597.79474944]
# Intercept:  1809821.2159409611
# C:\Users\Albert\AppData\Local\Temp\ipykernel_4352\806163288.py:20: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   linReg.fit(x[:, np.newaxis], y)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import pandas as pd

# Reads the csv-file
df = pd.read_csv('data_assignment2.csv')
area = 'Living_area'
price = 'Selling_price'

# Filters the data set to selling price above 2,4 million
filterOutliers = df[df[price] > 2400000]

#Variables with filtering
x = filterOutliers[area]
y = filterOutliers[price]

# Variable for linear regression and creates a 2D axis
linReg = LinearRegression(fit_intercept=True)
linReg.fit(x[:, np.newaxis], y)

# Variables for the slope and intercept from the sklearn.linear_model library
slope = linReg.coef_
intercept = linReg.intercept_

# y = kx + m, given a value x
def predictionFunc(x):
    return slope * x + intercept

# Prints out the predicted prices
print('Predicted price for 100 m^2: ', predictionFunc(100))
print('Predicted price for 150 m^2: ', predictionFunc(150))
print('Predicted price for 200 m^2: ', predictionFunc(200))
# Out:
# Predicted price for 100 m^2:  [4169600.69088546]
# Predicted price for 150 m^2:  [5349490.42835771]
# Predicted price for 200 m^2:  [6529380.16582996]
# C:\Users\Albert\AppData\Local\Temp\ipykernel_4352\2513205543.py:20: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   linReg.fit(x[:, np.newaxis], y)

# %%
import seaborn as sea
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import pandas as pd

# Reads the csv-file
df = pd.read_csv('data_assignment2.csv')
area = 'Living_area'
price = 'Selling_price'

# Filters the data set to selling price above 2,4 million
filterOutliers = df[df[price] > 2400000]

#Variables with filtering
x = filterOutliers[area]
y = filterOutliers[price]

# Variable for linear regression and creates a 2D axis
linReg = LinearRegression(fit_intercept=True)
linReg.fit(x[:, np.newaxis], y)

# Plots a resudial plot using the seaborn library
sea.residplot(x=x, y=y, data=filterOutliers)
plt.show()
# Out:
# C:\Users\Albert\AppData\Local\Temp\ipykernel_4352\2732616127.py:21: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   linReg.fit(x[:, np.newaxis], y)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay

# Loads the data set and pulls data from it
dataset = load_iris()
data = dataset.data
target = dataset.target
classifications = dataset.target_names

# Splits the data into a training set and a validation set, is later used in the classifier
dataTrain, dataTest, targetTrain, targetTest = train_test_split(data, target, random_state=0)

# Model that is too regularized (C too low) to see the impact on the results
classifier = svm.SVC(kernel="linear", C=100).fit(dataTrain, targetTrain)
np.set_printoptions(precision=2)

# Plot non-normalized and normalized confusion matrix
titles_options = [
    ("Confusion matrix, without normalization", None),
    ("Confusion matrix, with normalization", "true"),
]

for title, normalize in titles_options:
    disp = ConfusionMatrixDisplay.from_estimator(
        classifier,
        dataTest,
        targetTest,
        display_labels=classifications,
        cmap=plt.cm.Blues,
        normalize=normalize,
    )
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# Testing uniform-based k neighbors from 1 to 100
for i in range(1, 100, 5):
    kNeighborsUniform = KNeighborsClassifier(n_neighbors=i, weights='uniform')
    kNeighborsUniform.fit(dataTrain, targetTrain)
    targetPredUniform = kNeighborsUniform.predict(dataTest)

    print("Accuracy in percentage for uniform, given", i, "neighbors:",
          metrics.accuracy_score(targetTest, targetPredUniform) * 100, "%")

print(' ')

# Testing distance-based k neighbors from 1 to 100
for i in range(1, 100, 5):
    kNeighborsDistance = KNeighborsClassifier(n_neighbors=i, weights='distance')
    kNeighborsDistance.fit(dataTrain, targetTrain)
    targetPredDistance = kNeighborsDistance.predict(dataTest)

    print("Accuracy in percentage for distance, given", i, "neighbors:",
          metrics.accuracy_score(targetTest, targetPredDistance) * 100, "%")
# Out:
# Accuracy in percentage for uniform, given 1 neighbors: 97.36842105263158 %
# Accuracy in percentage for uniform, given 6 neighbors: 97.36842105263158 %
# Accuracy in percentage for uniform, given 11 neighbors: 97.36842105263158 %
# Accuracy in percentage for uniform, given 16 neighbors: 97.36842105263158 %
# Accuracy in percentage for uniform, given 21 neighbors: 97.36842105263158 %
# Accuracy in percentage for uniform, given 26 neighbors: 94.73684210526315 %
# Accuracy in percentage for uniform, given 31 neighbors: 94.73684210526315 %
# Accuracy in percentage for uniform, given 36 neighbors: 94.73684210526315 %
# Accuracy in percentage for uniform, given 41 neighbors: 89.47368421052632 %
# Accuracy in percentage for uniform, given 46 neighbors: 89.47368421052632 %
# Accuracy in percentage for uniform, given 51 neighbors: 89.47368421052632 %
# Accuracy in percentage for uniform, given 56 neighbors: 89.47368421052632 %
# ...

# %%
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score, confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris

# Loads the data set and pulls data from it
dataset = load_iris()
data = dataset.data
target = dataset.target
classifications = dataset.target_names

# Splits the data into a training set and a validation set, is later used in the classifier
dataTrain, dataTest, targetTrain, targetTest = train_test_split(data, target, random_state=0)

# Variable for logistic regression using the sklearn.linear_model library
logRegress = LogisticRegression()
logRegress.fit(dataTrain, targetTrain)

# Makes a prediction on the test data
targetPrediction = logRegress.predict(dataTest)

# Prints out the confusion matrix as well as the classification report
print(confusion_matrix(targetTest, targetPrediction))
print(classification_report(targetTest, targetPrediction))
# Out:
# [[13  0  0]
#  [ 0 15  1]
#  [ 0  0  9]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      0.94      0.97        16
#            2       0.90      1.00      0.95         9
#
#     accuracy                           0.97        38
#    macro avg       0.97      0.98      0.97        38
# weighted avg       0.98      0.97      0.97        38
# C:\Users\Albert\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score, confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris

# Loads the data set and pulls data from it
dataset = load_iris()
data = dataset.data
target = dataset.target
classifications = dataset.target_names

# Splits the data into a training set and a validation set, is later used in the classifier
dataTrain, dataTest, targetTrain, targetTest = train_test_split(data, target, random_state=0)

# Variable for the unifrom k-nearest neighbors algorithm where k = 100
kNeighborsUniform = KNeighborsClassifier(n_neighbors=100, weights='uniform')
kNeighborsUniform.fit(dataTrain, targetTrain)
targetPredUniform = kNeighborsUniform.predict(dataTest)

# Prints out the accuracy in percentage given 100 neighbors, the confusion matrix and the classification report
print("Accuracy in percentage for uniform, given", 100, "neighbors:",
      metrics.accuracy_score(targetTest, targetPredUniform) * 100, "%")
print(confusion_matrix(targetTest, targetPredUniform))
print(classification_report(targetTest, targetPredUniform))
# Out:
# Accuracy in percentage for uniform, given 100 neighbors: 60.526315789473685 %
# [[13  0  0]
#  [ 1  1 14]
#  [ 0  0  9]]
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        13
#            1       1.00      0.06      0.12        16
#            2       0.39      1.00      0.56         9
#
#     accuracy                           0.61        38
#    macro avg       0.77      0.69      0.55        38
# weighted avg       0.83      0.61      0.51        38
# ...
